# %%
import pandas as pd

# %%
#checking data in file can be used or not
data = pd.read_csv(".\source\survey_results_public.csv", index_col='ResponseId')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89184 entries, 1 to 89184
# Data columns (total 83 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Q120                                 89184 non-null  object
#  1   MainBranch                           89184 non-null  object
#  2   Age                                  89184 non-null  object
#  3   Employment                           87898 non-null  object
#  4   RemoteWork                           73810 non-null  object
#  5   CodingActivities                     73764 non-null  object
#  6   EdLevel                              87973 non-null  object
#  7   LearnCode                            87663 non-null  object
#  8   LearnCodeOnline                      70084 non-null  object
#  9   LearnCodeCoursesCert                 37076 non-null  object
#  10  YearsCode                            87435 non-null  object
# ...

# %%
data.head(20)
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 1           I agree                                      None of these
# 2           I agree                     I am a developer by profession
# 3           I agree                     I am a developer by profession
# 4           I agree                     I am a developer by profession
# 5           I agree                     I am a developer by profession
# 6           I agree                     I am a developer by profession
# 7           I agree                     I am a developer by profession
# 8           I agree                     I am a developer by profession
# 9           I agree  I am not primarily a developer, but I write co...
# 10          I agree                     I am a developer by profession
# 11          I agree                     I am a developer by profession
# 12          I agree                     I am a developer by profession
# ...

# %%
data.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
pd.set_option('display.max_columns', 85)
data
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
data.Employment.value_counts()
# Out:
# Employed, full-time                                                                                                                                                                                             53748
# Student, full-time                                                                                                                                                                                               7430
# Independent contractor, freelancer, or self-employed                                                                                                                                                             7076
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                         4354
# ...

# %%
data['OpSysProfessional use'].value_counts()
# Out:
# Windows                                                                                                     15943
# MacOS                                                                                                       12928
# Ubuntu                                                                                                       5201
# Windows;Windows Subsystem for Linux (WSL)                                                                    3934
# Ubuntu;Windows                                                                                               2795
#                                                                                                             ...
# Debian;iOS;iPadOS;MacOS;Red Hat;Windows                                                                         1
# BSD;Other Linux-based;Red Hat                                                                                   1
# ...

# %%
data.Employment[8992]
# Out:
# 'Employed, full-time;Employed, part-time'

# %%
data['DevType'].value_counts()
# Out:
# Developer, full-stack                            25735
# Developer, back-end                              13745
# Developer, front-end                              5071
# Developer, desktop or enterprise applications     3904
# Other (please specify):                           3080
# Developer, mobile                                 2597
# Engineering manager                               2033
# Student                                           1996
# Developer, embedded applications or devices       1845
# Data scientist or machine learning specialist     1588
# DevOps specialist                                 1387
# Academic researcher                               1354
# Research & Development role                       1353
# Senior Executive (C-Suite, VP, etc.)              1332
# Engineer, data                                    1248
# Cloud infrastructure engineer                     1036
# Developer, game or graphics                        866
# ...

# %%
macos_user = data[data['OpSysProfessional use'] =="MacOS"]
macos_user
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 6           I agree  I am a developer by profession     35-44 years old
# 7           I agree  I am a developer by profession     35-44 years old
# 17          I agree  I am a developer by profession     35-44 years old
# 18          I agree  I am a developer by profession     25-34 years old
# 21          I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89135       I agree     I code primarily as a hobby  Under 18 years old
# 89142       I agree  I am a developer by profession     25-34 years old
# 89154       I agree  I am a developer by profession     25-34 years old
# 89156       I agree  I am a developer by profession     25-34 years old
# 89157       I agree  I am a developer by profession     25-34 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# ...

# %%
data['Country'].value_counts()
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: Country, Length: 185, dtype: int64

# %%
India_developer = data[data['Country'] == "India"]
India_developer
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 10          I agree                     I am a developer by profession
# 67          I agree                     I am a developer by profession
# 79          I agree                     I am a developer by profession
# 83          I agree                     I am a developer by profession
# 86          I agree                     I am a developer by profession
# ...             ...                                                ...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# 89165       I agree                     I am a developer by profession
# 89166       I agree                     I am a developer by profession
# 89168       I agree                     I am a developer by profession
#
#                         Age                              Employment  \
# ResponseId
# ...

# %%
India_developer['Age'].value_counts()
# Out:
# 18-24 years old       2296
# 25-34 years old       2289
# 35-44 years old        512
# Under 18 years old     378
# 45-54 years old        107
# 55-64 years old         20
# Prefer not to say       19
# 65 years or older        4
# Name: Age, dtype: int64

# %%
data[(data['CodingActivities']=="Hobby") & (data['Country']=='India')  & (data['Employment']=='Employed, full-time')]
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 79          I agree  I am a developer by profession  18-24 years old
# 83          I agree  I am a developer by profession  25-34 years old
# 173         I agree  I am a developer by profession  18-24 years old
# 398         I agree  I am a developer by profession  18-24 years old
# 405         I agree  I am a developer by profession  25-34 years old
# ...             ...                             ...              ...
# 87461       I agree  I am a developer by profession  25-34 years old
# 87487       I agree  I am a developer by profession  18-24 years old
# 87527       I agree  I am a developer by profession  35-44 years old
# 87725       I agree  I am a developer by profession  18-24 years old
# 88038       I agree  I am a developer by profession  18-24 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# ...

# %%
filter = (data['Country']=="India") & (data['RemoteWork']=="Remote") & (data['ConvertedCompYearly']>100000)
data[filter].LanguageHaveWorkedWith.value_counts()
# Out:
# C++;HTML/CSS;JavaScript;Python                                                                                                                                                                                                                                                            1
# HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;Rust;SQL                                                                                                                                                                                                                                       1
# C++;Go;Java;JavaScript;Python                                                                                                                                                                                                                                                             1
# ...

# %%
data
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
survey = pd.read_csv('.\source\survey_results_schema.csv', index_col='qname')
survey
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# Q310         QID310  <div><span style="font-size:19px;"><strong>You...
# Q120         QID312
# S1             QID1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# Knowledge_7  QID289  Waiting on answers to questions often causes i...
# Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# Frequency_1  QID290  Needing help from people outside of your immed...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# ...

# %%
survey.loc['Knowledge_1'].question
# Out:
# 'I have interactions with people outside of my immediate team.'

# %%
data.query('Country == "India"') # This makes more sense whenever we have to go ahead and combine multiple conditions together
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 10          I agree                     I am a developer by profession
# 67          I agree                     I am a developer by profession
# 79          I agree                     I am a developer by profession
# 83          I agree                     I am a developer by profession
# 86          I agree                     I am a developer by profession
# ...             ...                                                ...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# 89165       I agree                     I am a developer by profession
# 89166       I agree                     I am a developer by profession
# 89168       I agree                     I am a developer by profession
#
#                         Age                              Employment  \
# ResponseId
# ...

# %%
data.query("ConvertedCompYearly>100000 & Country == 'India'")
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 5411        I agree                     I am a developer by profession
# 9702        I agree                     I am a developer by profession
# 9725        I agree  I am not primarily a developer, but I write co...
# 10000       I agree                     I am a developer by profession
# 10440       I agree                     I am a developer by profession
# 10953       I agree                     I am a developer by profession
# 11014       I agree                     I am a developer by profession
# 12465       I agree  I am not primarily a developer, but I write co...
# 12709       I agree                     I am a developer by profession
# 13779       I agree                     I am a developer by profession
# 17522       I agree                     I am a developer by profession
# 18954       I agree                     I am a developer by profession
# ...

# %%
data['YearsCodePro'] = pd.to_numeric(data['YearsCodePro'],errors='coerce')

# %%
data.query('ConvertedCompYearly>100000 & Country == "India" & YearsCodePro < 12')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 5411        I agree                     I am a developer by profession
# 9702        I agree                     I am a developer by profession
# 10000       I agree                     I am a developer by profession
# 12465       I agree  I am not primarily a developer, but I write co...
# 12709       I agree                     I am a developer by profession
# 13779       I agree                     I am a developer by profession
# 17522       I agree                     I am a developer by profession
# 18954       I agree                     I am a developer by profession
# 19082       I agree                     I am a developer by profession
# 31075       I agree                     I am a developer by profession
# 31202       I agree                     I am a developer by profession
# 36065       I agree                     I am a developer by profession
# ...
